# %% [markdown]
# Week 8 Assignment

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# Load Data

# %%
mpg = pd.read_csv(r'C:\Users\khiru\OneDrive\Desktop\IS362\auto-mpg.data', header=None, delim_whitespace=True)
mpg
# Out:
#         0  1      2      3       4     5   6  7                          8
# 0    18.0  8  307.0  130.0  3504.0  12.0  70  1  chevrolet chevelle malibu
# 1    15.0  8  350.0  165.0  3693.0  11.5  70  1          buick skylark 320
# 2    18.0  8  318.0  150.0  3436.0  11.0  70  1         plymouth satellite
# 3    16.0  8  304.0  150.0  3433.0  12.0  70  1              amc rebel sst
# 4    17.0  8  302.0  140.0  3449.0  10.5  70  1                ford torino
# ..    ... ..    ...    ...     ...   ...  .. ..                        ...
# 393  27.0  4  140.0  86.00  2790.0  15.6  82  1            ford mustang gl
# 394  44.0  4   97.0  52.00  2130.0  24.6  82  2                  vw pickup
# 395  32.0  4  135.0  84.00  2295.0  11.6  82  1              dodge rampage
# 396  28.0  4  120.0  79.00  2625.0  18.6  82  1                ford ranger
# 397  31.0  4  119.0  82.00  2720.0  19.4  82  1                 chevy s-10
#
# [398 rows x 9 columns]

# %% [markdown]
# TASK 3

# %%
col = ['mpg',  'cylinders','displacement','horsepower', 'weight','acceleration','model_yr','origin','car_name']
mpg.columns = col
mpg
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  model_yr  \
# 0    18.0          8         307.0      130.0  3504.0          12.0        70
# 1    15.0          8         350.0      165.0  3693.0          11.5        70
# 2    18.0          8         318.0      150.0  3436.0          11.0        70
# 3    16.0          8         304.0      150.0  3433.0          12.0        70
# 4    17.0          8         302.0      140.0  3449.0          10.5        70
# ..    ...        ...           ...        ...     ...           ...       ...
# 393  27.0          4         140.0      86.00  2790.0          15.6        82
# 394  44.0          4          97.0      52.00  2130.0          24.6        82
# 395  32.0          4         135.0      84.00  2295.0          11.6        82
# 396  28.0          4         120.0      79.00  2625.0          18.6        82
# 397  31.0          4         119.0      82.00  2720.0          19.4        82
#
# ...

# %% [markdown]
# Task 4

# %%
mpg.horsepower = mpg.horsepower.replace('?', np.nan)
mpg.horsepower = pd.to_numeric(mpg.horsepower)
mpg.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower      float64
# weight          float64
# acceleration    float64
# model_yr          int64
# origin            int64
# car_name         object
# dtype: object

# %% [markdown]
# Task 5

# %%
origins = {1: 'USA', 
          2: 'Asia',
          3: 'Europe'}

mpg.origin = mpg.origin.map(origins)
mpg
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0  3504.0          12.0
# 1    15.0          8         350.0       165.0  3693.0          11.5
# 2    18.0          8         318.0       150.0  3436.0          11.0
# 3    16.0          8         304.0       150.0  3433.0          12.0
# 4    17.0          8         302.0       140.0  3449.0          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0  2790.0          15.6
# 394  44.0          4          97.0        52.0  2130.0          24.6
# 395  32.0          4         135.0        84.0  2295.0          11.6
# 396  28.0          4         120.0        79.0  2625.0          18.6
# 397  31.0          4         119.0        82.0  2720.0          19.4
#
#      model_yr origin                   car_name
# 0          70    USA  chevrolet chevelle malibu
# ...

# %% [markdown]
# Task 6

# %%
a = sns.countplot(x="cylinders", hue='origin' ,data=mpg)
plt.xlabel("Cylinders",size = 10)
plt.ylabel("Count",size = 10)
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# Task 7

# %%
b = sns.regplot(x="horsepower", y="weight", data=mpg, color='y')
plt.title('HorsePower and Weight Relation', fontsize=10)
plt.xlabel("Horsepower",size = 10)
plt.ylabel("Weight",size = 10)
# Out:
# Text(0, 0.5, 'Weight')

# %% [markdown]
# Task 8

# %%
sns.lmplot("model_yr", "mpg", data=mpg, hue='origin', fit_reg=True)
